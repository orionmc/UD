# %%
import requests
from bs4 import BeautifulSoup
import time
from urllib.parse import urljoin
from tabulate import tabulate
import json
from datetime import datetime
import re

# Constants
BASE_URL = "https://www.gsmarena.com/"
APPLE_PHONES_URL = "https://www.gsmarena.com/apple-phones-48.php" 
HEADERS = {                     # User-Agent to avoid bot detection
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/85.0.4183.102 Safari/537.36"
    )
}
REQUEST_DELAY = 1  # Seconds between requests to respect rate limiting

# Define Year Range
YEAR_FROM = 2022
YEAR_TO = datetime.now().year  # Present year

# Define the specifications to extract with their corresponding data-spec attributes
DESIRED_SPECS = {
    'Display Size': 'displaysize',
    'Display Resolution': 'displayresolution',
    'Battery Size': 'batdescription1',
    'Memory': 'internalmemory',
    'Front Camera': 'cam2modules',
    'Back Camera': 'cam1modules',
    'Weight': 'weight',
    'Dimension': 'dimensions'
}

def get_total_pages():
    try:
        response = requests.get(APPLE_PHONES_URL, headers=HEADERS)
        response.raise_for_status()
    except requests.RequestException as e:
        print(f"Error fetching Apple phones page: {e}")
        return 1  

    soup = BeautifulSoup(response.text, 'html.parser')
    pagination = soup.find('div', class_='nav-pages')
    if not pagination:
        return 1  
    pages = pagination.find_all('a')
    page_numbers = [int(page.text) for page in pages if page.text.isdigit()]
    return max(page_numbers) if page_numbers else 1

def get_apple_phone_links(total_pages):

    phone_links = []
    for page in range(1, total_pages + 1):
        if page == 1:
            url = APPLE_PHONES_URL
        else:
            url = f"https://www.gsmarena.com/apple-phones-f-{page}.php"
        
        print(f"Fetching Apple phones list from page {page}...")
        try:
            response = requests.get(url, headers=HEADERS)
            response.raise_for_status()
        except requests.RequestException as e:
            print(f"Failed to fetch page {page}: {e}")
            continue

        soup = BeautifulSoup(response.text, 'html.parser')
        phone_table = soup.find('div', class_='makers')
        if not phone_table:
            print(f"No phone table found on page {page}.")
            continue

        phones = phone_table.find_all('a')
        for phone in phones:
            href = phone.get('href')
            full_url = urljoin(BASE_URL, href)
            phone_links.append(full_url)
        
        time.sleep(REQUEST_DELAY)  

    return phone_links

def extract_release_year(phone_soup):

    year_td = phone_soup.find('td', {'class': 'nfo', 'data-spec': 'year'})
    if year_td:
        text = year_td.get_text(separator=" ", strip=True)
        match = re.search(r'\b(20\d{2}|19\d{2})\b', text)
        if match:
            return int(match.group(0))
    return None

def get_spec_value(phone_soup, data_spec):
    
    spec_td = phone_soup.find('td', {'class': 'nfo', 'data-spec': data_spec})
    if spec_td:
        for sup in spec_td.find_all(['sup', 'a']):
            sup.decompose()
        return spec_td.get_text(separator=" ", strip=True)
    return "N/A"

def get_specs(phone_url):
    try:
        response = requests.get(phone_url, headers=HEADERS)
        response.raise_for_status()
    except requests.RequestException as e:
        print(f"Failed to fetch phone page: {phone_url}. Error: {e}")
        return None

    soup = BeautifulSoup(response.text, 'html.parser')
    specs = {}

    name_tag = soup.find('h1', class_='specs-phone-name-title')
    if name_tag:
        specs['Phone Name'] = name_tag.text.strip()
    else:
        specs['Phone Name'] = "Unknown"

    release_year = extract_release_year(soup)
    specs['Release Year'] = release_year if release_year else "Unknown"

    for spec_name, data_spec in DESIRED_SPECS.items():
        spec_value = get_spec_value(soup, data_spec)
        specs[spec_name] = spec_value

    return specs

def display_specs_table(specs_list):

    if not specs_list:
        print("No specifications to display.")
        return

    headers = ["Phone Name", "Release Year"] + list(DESIRED_SPECS.keys())
    table = []

    for specs in specs_list:
        row = [
            specs.get('Phone Name', 'N/A'),
            specs.get('Release Year', 'N/A'),
            specs.get('Display Size', 'N/A'),
            specs.get('Display Resolution', 'N/A'),
            specs.get('Battery Size', 'N/A'),
            specs.get('Memory', 'N/A'),
            specs.get('Front Camera', 'N/A'),
            specs.get('Back Camera', 'N/A'),
            specs.get('Weight', 'N/A'),
            specs.get('Dimension', 'N/A')
        ]
        table.append(row)

    print(tabulate(table, headers=headers, tablefmt="grid"))

def main():
    print(f"Fetching Apple phone models released from {YEAR_FROM} to {YEAR_TO}...\n")

    total_pages = get_total_pages()
    phone_links = get_apple_phone_links(total_pages)

    print(f"\nTotal Apple phones found: {len(phone_links)}")
    filtered_phones = []

    for idx, phone_url in enumerate(phone_links, 1):
        print(f"\nProcessing ({idx}/{len(phone_links)}): {phone_url}")
        specs = get_specs(phone_url)
        if not specs:
            print("Skipping due to failed specs retrieval.")
            continue

        release_year = specs.get('Release Year')
        if isinstance(release_year, int) and YEAR_FROM <= release_year <= YEAR_TO:
            filtered_phones.append(specs)
            print(f"Included: {specs.get('Phone Name')} ({release_year})")
        else:
            print(f"Excluded: Release Year {release_year} not in range.")

        time.sleep(REQUEST_DELAY)  

    print(f"\nTotal Apple phones released between {YEAR_FROM} and {YEAR_TO}: {len(filtered_phones)}\n")
    display_specs_table(filtered_phones)

    if not filtered_phones:
        print("No phones found in the specified range.")
    else:
        # Save the specs to a JSON file
        output_filename = f"apple_phones_{YEAR_FROM}_{YEAR_TO}.json"
        try:
            with open(output_filename, 'w', encoding='utf-8') as f:
                json.dump(filtered_phones, f, ensure_ascii=False, indent=4)
            print(f"\nSpecifications saved to {output_filename}")
        except IOError as e:
            print(f"Failed to save specifications to {output_filename}. Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# Fetching Apple phone models released from 2015 to 2025...
#
# Fetching Apple phones list from page 1...
# Fetching Apple phones list from page 2...
# Failed to fetch page 2: 404 Client Error: Not Found for url: https://www.gsmarena.com/apple-phones-f-2.php
# Fetching Apple phones list from page 3...
# Failed to fetch page 3: 404 Client Error: Not Found for url: https://www.gsmarena.com/apple-phones-f-3.php
#
# Total Apple phones found: 50
#
# Processing (1/50): https://www.gsmarena.com/apple_ipad_mini_(2024)-13437.php
# Included: Apple iPad mini (2024) (2024)
#
# Processing (2/50): https://www.gsmarena.com/apple_iphone_16_pro_max-13123.php
# Included: Apple iPhone 16 Pro Max (2024)
#
# Processing (3/50): https://www.gsmarena.com/apple_iphone_16_pro-13315.php
# Included: Apple iPhone 16 Pro (2024)
#
# Processing (4/50): https://www.gsmarena.com/apple_iphone_16_plus-13316.php
# Included: Apple iPhone 16 Plus (2024)
#
# Processing (5/50): https://www.gsmarena.com/apple_iphone_16-13317.php
# Included: Apple iPhone 16 (2024)
#
# Processing (6/50): https://www.gsmarena.com/apple_watch_series_10-13318.php
# Included: Apple Watch Series 10 (2024)
#
# Processing (7/50): https://www.gsmarena.com/apple_watch_series_10_aluminum-13319.php
# Included: Apple Watch Series 10 Aluminum (2024)
#
# Processing (8/50): https://www.gsmarena.com/apple_ipad_pro_13_(2024)-12987.php
# Included: Apple iPad Pro 13 (2024) (2024)
#
# Processing (9/50): https://www.gsmarena.com/apple_ipad_pro_11_(2024)-12986.php
# Included: Apple iPad Pro 11 (2024) (2024)
#
# Processing (10/50): https://www.gsmarena.com/apple_ipad_air_13_(2024)-12985.php
# Included: Apple iPad Air 13 (2024) (2024)
#
# Processing (11/50): https://www.gsmarena.com/apple_ipad_air_11_(2024)-12984.php
# Included: Apple iPad Air 11 (2024) (2024)
#
# Processing (12/50): https://www.gsmarena.com/apple_iphone_15_pro_max-12548.php
# Included: Apple iPhone 15 Pro Max (2023)
#
# Processing (13/50): https://www.gsmarena.com/apple_iphone_15_pro-12557.php
# Included: Apple iPhone 15 Pro (2023)
#
# Processing (14/50): https://www.gsmarena.com/apple_iphone_15_plus-12558.php
# Included: Apple iPhone 15 Plus (2023)
#
# Processing (15/50): https://www.gsmarena.com/apple_iphone_15-12559.php
# Included: Apple iPhone 15 (2023)
#
# Processing (16/50): https://www.gsmarena.com/apple_watch_ultra_2-12560.php
# Included: Apple Watch Ultra 2 (2023)
#
# Processing (17/50): https://www.gsmarena.com/apple_watch_series_9-12561.php
# Included: Apple Watch Series 9 (2023)
#
# Processing (18/50): https://www.gsmarena.com/apple_watch_series_9_aluminum-12562.php
# Included: Apple Watch Series 9 Aluminum (2023)
#
# Processing (19/50): https://www.gsmarena.com/apple_ipad_pro_12_9_(2022)-11939.php
# Included: Apple iPad Pro 12.9 (2022) (2022)
#
# Processing (20/50): https://www.gsmarena.com/apple_ipad_pro_11_(2022)-11940.php
# Included: Apple iPad Pro 11 (2022) (2022)
#
# Processing (21/50): https://www.gsmarena.com/apple_ipad_(2022)-11941.php
# Included: Apple iPad (2022) (2022)
#
# Processing (22/50): https://www.gsmarena.com/apple_iphone_14_pro_max-11773.php
# Included: Apple iPhone 14 Pro Max (2022)
#
# Processing (23/50): https://www.gsmarena.com/apple_iphone_14_pro-11860.php
# Included: Apple iPhone 14 Pro (2022)
#
# Processing (24/50): https://www.gsmarena.com/apple_iphone_14_plus-11862.php
# Included: Apple iPhone 14 Plus (2022)
#
# Processing (25/50): https://www.gsmarena.com/apple_iphone_14-11861.php
# Included: Apple iPhone 14 (2022)
#
# Processing (26/50): https://www.gsmarena.com/apple_watch_ultra-11827.php
# Included: Apple Watch Ultra (2022)
#
# Processing (27/50): https://www.gsmarena.com/apple_watch_series_8-11866.php
# Included: Apple Watch Series 8 (2022)
#
# Processing (28/50): https://www.gsmarena.com/apple_watch_series_8_aluminum-11864.php
# Included: Apple Watch Series 8 Aluminum (2022)
#
# Processing (29/50): https://www.gsmarena.com/apple_watch_se_(2022)-11865.php
# Included: Apple Watch SE (2022) (2022)
#
# Processing (30/50): https://www.gsmarena.com/apple_iphone_se_(2022)-11410.php
# Included: Apple iPhone SE (2022) (2022)
#
# Processing (31/50): https://www.gsmarena.com/apple_ipad_air_(2022)-11411.php
# Included: Apple iPad Air (2022) (2022)
#
# Processing (32/50): https://www.gsmarena.com/apple_iphone_13_pro_max-11089.php
# Included: Apple iPhone 13 Pro Max (2021)
#
# Processing (33/50): https://www.gsmarena.com/apple_iphone_13_pro-11102.php
# Included: Apple iPhone 13 Pro (2021)
#
# Processing (34/50): https://www.gsmarena.com/apple_iphone_13-11103.php
# Included: Apple iPhone 13 (2021)
#
# Processing (35/50): https://www.gsmarena.com/apple_iphone_13_mini-11104.php
# Included: Apple iPhone 13 mini (2021)
#
# Processing (36/50): https://www.gsmarena.com/apple_ipad_mini_(2021)-11105.php
# Included: Apple iPad mini (2021) (2021)
#
# Processing (37/50): https://www.gsmarena.com/apple_ipad_10_2_(2021)-11106.php
# Included: Apple iPad 10.2 (2021) (2021)
#
# Processing (38/50): https://www.gsmarena.com/apple_watch_edition_series_7-11147.php
# Included: Apple Watch Edition Series 7 (2021)
#
# Processing (39/50): https://www.gsmarena.com/apple_watch_series_7-11146.php
# Included: Apple Watch Series 7 (2021)
#
# Processing (40/50): https://www.gsmarena.com/apple_watch_series_7_aluminum-11107.php
# Included: Apple Watch Series 7 Aluminum (2021)
#
# Processing (41/50): https://www.gsmarena.com/apple_ipad_pro_12_9_(2021)-10864.php
# Included: Apple iPad Pro 12.9 (2021) (2021)
#
# Processing (42/50): https://www.gsmarena.com/apple_ipad_pro_11_(2021)-10865.php
# Included: Apple iPad Pro 11 (2021) (2021)
#
# Processing (43/50): https://www.gsmarena.com/apple_iphone_12_pro_max-10237.php
# Included: Apple iPhone 12 Pro Max (2020)
#
# Processing (44/50): https://www.gsmarena.com/apple_iphone_12_pro-10508.php
# Included: Apple iPhone 12 Pro (2020)
#
# Processing (45/50): https://www.gsmarena.com/apple_iphone_12-10509.php
# Included: Apple iPhone 12 (2020)
#
# Processing (46/50): https://www.gsmarena.com/apple_iphone_12_mini-10510.php
# Included: Apple iPhone 12 mini (2020)
#
# Processing (47/50): https://www.gsmarena.com/apple_ipad_air_(2020)-10444.php
# Included: Apple iPad Air (2020) (2020)
#
# Processing (48/50): https://www.gsmarena.com/apple_ipad_10_2_(2020)-10445.php
# Included: Apple iPad 10.2 (2020) (2020)
#
# Processing (49/50): https://www.gsmarena.com/apple_watch_se-10446.php
# Included: Apple Watch SE (2020)
#
# Processing (50/50): https://www.gsmarena.com/apple_watch_series_6_aluminum-10447.php
# Included: Apple Watch Series 6 Aluminum (2020)
#
# Total Apple phones released between 2015 and 2025: 50
#
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Phone Name                     |   Release Year | Display Size                                        | Display Resolution                                  | Battery Size               | Memory                                                                  | Front Camera                                                                                | Back Camera                                                                                                                                                                                                                                                                                        | Weight                                              | Dimension                                       |
# +================================+================+=====================================================+=====================================================+============================+=========================================================================+=============================================================================================+====================================================================================================================================================================================================================================================================================================+=====================================================+=================================================+
# | Apple iPad mini (2024)         |           2024 | 8.3 inches, 203.9 cm (~77.4% screen-to-body ratio)  | 1488 x 2266 pixels, 3:2 ratio (~327 ppi density)    | Li-Ion 5078 mAh (19.3 Wh)  | 128GB 8GB RAM, 256GB 8GB RAM, 512GB 8GB RAM                             | 12 MP, f/2.4, 122˚ (ultrawide)                                                              | 12 MP, f/1.8, (wide), AF                                                                                                                                                                                                                                                                           | 293 g (Wi-Fi) / 297 g (Wi-Fi + Cellular) (10.34 oz) | 195.4 x 134.8 x 6.3 mm (7.69 x 5.31 x 0.25 in)  |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPhone 16 Pro Max        |           2024 | 6.9 inches, 115.6 cm (~91.4% screen-to-body ratio)  | 1320 x 2868 pixels, 19.5:9 ratio (~460 ppi density) | Li-Ion 4685 mAh            | 256GB 8GB RAM, 512GB 8GB RAM, 1TB 8GB RAM                               | 12 MP, f/1.9, 23mm (wide), 1/3.6", PDAF, OIS SL 3D, (depth/biometrics sensor)               | 48 MP, f/1.8, 24mm (wide), 1/1.28", 1.22µm, dual pixel PDAF, sensor-shift OIS 12 MP, f/2.8, 120mm (periscope telephoto), 1/3.06", 1.12µm, dual pixel PDAF, 3D sensor‑shift OIS, 5x optical zoom 48 MP, f/2.2, 13mm (ultrawide), 0.7µm, PDAF TOF 3D LiDAR scanner (depth)                           | 227 g (8.01 oz)                                     | 163 x 77.6 x 8.3 mm (6.42 x 3.06 x 0.33 in)     |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPhone 16 Pro            |           2024 | 6.3 inches, 96.4 cm (~90.1% screen-to-body ratio)   | 1206 x 2622 pixels, 19.5:9 ratio (~460 ppi density) | Li-Ion 3582 mAh            | 128GB 8GB RAM, 256GB 8GB RAM, 512GB 8GB RAM, 1TB 8GB RAM                | 12 MP, f/1.9, 23mm (wide), 1/3.6", PDAF, OIS SL 3D, (depth/biometrics sensor)               | 48 MP, f/1.8, 24mm (wide), 1/1.28", 1.22µm, dual pixel PDAF, sensor-shift OIS 12 MP, f/2.8, 120mm (periscope telephoto), 1/3.06", 1.12µm, dual pixel PDAF, 3D sensor‑shift OIS, 5x optical zoom 48 MP, f/2.2, 13mm (ultrawide), 0.7µm, PDAF TOF 3D LiDAR scanner (depth)                           | 199 g (7.02 oz)                                     | 149.6 x 71.5 x 8.3 mm (5.89 x 2.81 x 0.33 in)   |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPhone 16 Plus           |           2024 | 6.7 inches, 110.2 cm (~88.0% screen-to-body ratio)  | 1290 x 2796 pixels, 19.5:9 ratio (~460 ppi density) | Li-Ion 4674 mAh            | 128GB 8GB RAM, 256GB 8GB RAM, 512GB 8GB RAM                             | 12 MP, f/1.9, 23mm (wide), 1/3.6", PDAF SL 3D, (depth/biometrics sensor)                    | 48 MP, f/1.6, 26mm (wide), 1/1.56", 1.0µm, dual pixel PDAF, sensor-shift OIS 12 MP, f/2.2, 13mm, 120˚ (ultrawide), 0.7µm, dual pixel PDAF                                                                                                                                                          | 199 g (7.02 oz)                                     | 160.9 x 77.8 x 7.8 mm (6.33 x 3.06 x 0.31 in)   |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPhone 16                |           2024 | 6.1 inches, 91.7 cm (~86.8% screen-to-body ratio)   | 1179 x 2556 pixels, 19.5:9 ratio (~460 ppi density) | Li-Ion 3561 mAh            | 128GB 8GB RAM, 256GB 8GB RAM, 512GB 8GB RAM                             | 12 MP, f/1.9, 23mm (wide), 1/3.6", PDAF SL 3D, (depth/biometrics sensor)                    | 48 MP, f/1.6, 26mm (wide), 1/1.56", 1.0µm, dual pixel PDAF, sensor-shift OIS 12 MP, f/2.2, 13mm, 120˚ (ultrawide), 0.7µm, dual pixel PDAF                                                                                                                                                          | 170 g (6.00 oz)                                     | 147.6 x 71.6 x 7.8 mm (5.81 x 2.82 x 0.31 in)   |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple Watch Series 10          |           2024 | 1.96 inches                                         | 496 x 416 pixels (~330 ppi density)                 | Li-Ion 327 mAh             | 64GB                                                                    | N/A                                                                                         | No                                                                                                                                                                                                                                                                                                 | 34.4 g (42mm), 41.7 g (46mm) (1.48 oz)              | 46 x 39 x 9.7 mm (1.81 x 1.54 x 0.38 in)        |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple Watch Series 10 Aluminum |           2024 | 1.96 inches                                         | 496 x 416 pixels (~330 ppi density)                 | Li-Ion 327 mAh             | 64GB                                                                    | N/A                                                                                         | No                                                                                                                                                                                                                                                                                                 | 29.3 g (42mm), 35.3 g (46mm) (1.02 oz)              | 46 x 39 x 9.7 mm (1.81 x 1.54 x 0.38 in)        |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPad Pro 13 (2024)       |           2024 | 13.0 inches, 527.3 cm (~86.9% screen-to-body ratio) | 2064 x 2752 pixels, 4:3 ratio (~264 ppi density)    | Li-Po 10290 mAh            | 256GB 8GB RAM, 512GB 8GB RAM, 1TB 16GB RAM, 2TB 16GB RAM                | 12 MP, f/2.4, 122˚ (ultrawide)                                                              | 12 MP, f/1.8, (wide), dual pixel PDAF TOF 3D LiDAR scanner (depth)                                                                                                                                                                                                                                 | 579 g (Wi-Fi), 582 g (5G) (1.28 lb)                 | 281.6 x 215.5 x 5.1 mm (11.09 x 8.48 x 0.20 in) |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPad Pro 11 (2024)       |           2024 | 11.0 inches, 373.1 cm (~84.2% screen-to-body ratio) | 1668 x 2420 pixels, 3:2 ratio (~264 ppi density)    | Li-Po 8160 mAh             | 256GB 8GB RAM, 512GB 8GB RAM, 1TB 16GB RAM, 2TB 16GB RAM                | 12 MP, f/2.4, 122˚ (ultrawide)                                                              | 12 MP, f/1.8, (wide), dual pixel PDAF TOF 3D LiDAR scanner (depth)                                                                                                                                                                                                                                 | 444 g (Wi-Fi), 446 g (5G) (1.03 lb)                 | 249.7 x 177.5 x 5.3 mm (9.83 x 6.99 x 0.21 in)  |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPad Air 13 (2024)       |           2024 | 13.0 inches, 519.3 cm (~86.1% screen-to-body ratio) | 2048 x 2732 pixels, 4:3 ratio (~264 ppi density)    | Li-Po 9705 mAh (36.59 Wh)  | 128GB 8GB RAM, 256GB 8GB RAM, 512GB 8GB RAM, 1TB 8GB RAM                | 12 MP, f/2.0, 122˚ (ultrawide)                                                              | 12 MP, f/1.8, (wide), 1/3.0", 1.22µm, dual pixel PDAF                                                                                                                                                                                                                                              | 617 g (Wi-Fi) / 618 g (5G) (1.36 lb)                | 280.6 x 214.9 x 6.1 mm (11.05 x 8.46 x 0.24 in) |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPad Air 11 (2024)       |           2024 | 11.0 inches, 357.6 cm (~80.9% screen-to-body ratio) | 1640 x 2360 pixels (~264 ppi density)               | Li-Po 7606 mAh (28.93 Wh)  | 128GB 8GB RAM, 256GB 8GB RAM, 512GB 8GB RAM, 1TB 8GB RAM                | 12 MP, f/2.0, 122˚ (ultrawide)                                                              | 12 MP, f/1.8, (wide), 1/3.0", 1.22µm, dual pixel PDAF                                                                                                                                                                                                                                              | 462 g (1.02 lb)                                     | 247.6 x 178.5 x 6.1 mm (9.75 x 7.03 x 0.24 in)  |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPhone 15 Pro Max        |           2023 | 6.7 inches, 110.2 cm (~89.8% screen-to-body ratio)  | 1290 x 2796 pixels, 19.5:9 ratio (~460 ppi density) | Li-Ion 4441 mAh            | 256GB 8GB RAM, 512GB 8GB RAM, 1TB 8GB RAM                               | 12 MP, f/1.9, 23mm (wide), 1/3.6", PDAF, OIS SL 3D, (depth/biometrics sensor)               | 48 MP, f/1.8, 24mm (wide), 1/1.28", 1.22µm, dual pixel PDAF, sensor-shift OIS 12 MP, f/2.8, 120mm (periscope telephoto), 1/3.06", 1.12µm, dual pixel PDAF, 3D sensor‑shift OIS, 5x optical zoom 12 MP, f/2.2, 13mm, 120˚ (ultrawide), 1/2.55", 1.4µm, dual pixel PDAF TOF 3D LiDAR scanner (depth) | 221 g (7.80 oz)                                     | 159.9 x 76.7 x 8.3 mm (6.30 x 3.02 x 0.33 in)   |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPhone 15 Pro            |           2023 | 6.1 inches, 91.3 cm (~88.2% screen-to-body ratio)   | 1179 x 2556 pixels, 19.5:9 ratio (~461 ppi density) | Li-Ion 3274 mAh            | 128GB 8GB RAM, 256GB 8GB RAM, 512GB 8GB RAM, 1TB 8GB RAM                | 12 MP, f/1.9, 23mm (wide), 1/3.6", PDAF, OIS SL 3D, (depth/biometrics sensor)               | 48 MP, f/1.8, 24mm (wide), 1/1.28", 1.22µm, dual pixel PDAF, sensor-shift OIS 12 MP, f/2.8, 77mm (telephoto), 1/3.5", 1.0µm, PDAF, OIS, 3x optical zoom 12 MP, f/2.2, 13mm, 120˚ (ultrawide), 1/2.55", 1.4µm, dual pixel PDAF TOF 3D LiDAR scanner (depth)                                         | 187 g (6.60 oz)                                     | 146.6 x 70.6 x 8.3 mm (5.77 x 2.78 x 0.33 in)   |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPhone 15 Plus           |           2023 | 6.7 inches, 110.2 cm (~88.0% screen-to-body ratio)  | 1290 x 2796 pixels, 19.5:9 ratio (~460 ppi density) | Li-Ion 4383 mAh            | 128GB 6GB RAM, 256GB 6GB RAM, 512GB 6GB RAM                             | 12 MP, f/1.9, 23mm (wide), 1/3.6", PDAF SL 3D, (depth/biometrics sensor)                    | 48 MP, f/1.6, 26mm (wide), 1/1.56", 1.0µm, dual pixel PDAF, sensor-shift OIS 12 MP, f/2.4, 13mm, 120˚ (ultrawide), 0.7µm                                                                                                                                                                           | 201 g (7.09 oz)                                     | 160.9 x 77.8 x 7.8 mm (6.33 x 3.06 x 0.31 in)   |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPhone 15                |           2023 | 6.1 inches, 91.3 cm (~86.4% screen-to-body ratio)   | 1179 x 2556 pixels, 19.5:9 ratio (~461 ppi density) | Li-Ion 3349 mAh            | 128GB 6GB RAM, 256GB 6GB RAM, 512GB 6GB RAM                             | 12 MP, f/1.9, 23mm (wide), 1/3.6", PDAF SL 3D, (depth/biometrics sensor)                    | 48 MP, f/1.6, 26mm (wide), 1/1.56", 1.0µm, dual pixel PDAF, sensor-shift OIS 12 MP, f/2.4, 13mm, 120˚ (ultrawide), 0.7µm                                                                                                                                                                           | 171 g (6.03 oz)                                     | 147.6 x 71.6 x 7.8 mm (5.81 x 2.82 x 0.31 in)   |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple Watch Ultra 2            |           2023 | 1.92 inches                                         | 502 x 410 pixels (~338 ppi density)                 | Li-Ion 564 mAh             | 64GB                                                                    | N/A                                                                                         | No                                                                                                                                                                                                                                                                                                 | 61.4 g or 61.8 g (black) (2.15 oz)                  | 49 x 44 x 14.4 mm (1.93 x 1.73 x 0.57 in)       |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple Watch Series 9           |           2023 | 1.9 inches                                          | 484 x 396 pixels (~326 ppi density)                 | Li-Ion 308 mAh             | 64GB                                                                    | N/A                                                                                         | No                                                                                                                                                                                                                                                                                                 | 42.3 g (41mm), 51.5 g (45mm) (1.48 oz)              | 45 x 38 x 10.7 mm (1.77 x 1.50 x 0.42 in)       |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple Watch Series 9 Aluminum  |           2023 | 1.9 inches                                          | 484 x 396 pixels (~326 ppi density)                 | Li-Ion 308 mAh             | 64GB                                                                    | N/A                                                                                         | No                                                                                                                                                                                                                                                                                                 | 31.9 g (41mm), 38.7 g (45mm) (1.13 oz)              | 45 x 38 x 10.7 mm (1.77 x 1.50 x 0.42 in)       |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPad Pro 12.9 (2022)     |           2022 | 12.9 inches, 515.3 cm (~85.4% screen-to-body ratio) | 2048 x 2732 pixels, 4:3 ratio (~265 ppi density)    | Li-Po 10758 mAh (40.88 Wh) | 128GB 8GB RAM, 256GB 8GB RAM, 512GB 8GB RAM, 1TB 16GB RAM, 2TB 16GB RAM | 12 MP, f/2.4, 122˚ (ultrawide)                                                              | 12 MP, f/1.8, (wide), 1/3.0", 1.22µm, dual pixel PDAF 10 MP, f/2.4, 125˚ (ultrawide) TOF 3D LiDAR scanner (depth)                                                                                                                                                                                  | 682 g (Wi-Fi), 685 g (5G) (1.50 lb)                 | 280.6 x 214.9 x 6.4 mm (11.05 x 8.46 x 0.25 in) |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPad Pro 11 (2022)       |           2022 | 11.0 inches, 366.5 cm (~82.9% screen-to-body ratio) | 1668 x 2388 pixels (~265 ppi density)               | Li-Po 7538 mAh (28.65 Wh)  | 128GB 8GB RAM, 256GB 8GB RAM, 512GB 8GB RAM, 1TB 16GB RAM, 2TB 16GB RAM | 12 MP, f/2.4, 122˚ (ultrawide)                                                              | 12 MP, f/1.8, (wide), 1/3.0", 1.22µm, dual pixel PDAF 10 MP, f/2.4, 125˚ (ultrawide) TOF 3D LiDAR scanner (depth)                                                                                                                                                                                  | 466 g (Wi-Fi), 470 g (5G) (1.03 lb)                 | 247.6 x 178.5 x 5.9 mm (9.75 x 7.03 x 0.23 in)  |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPad (2022)              |           2022 | 10.9 inches, 359.2 cm (~80.5% screen-to-body ratio) | 1640 x 2360 pixels (~264 ppi density)               | Li-Po 7606 mAh (28.6 Wh)   | 64GB 4GB RAM, 256GB 4GB RAM                                             | 12 MP, f/2.4, 122˚ (ultrawide)                                                              | 12 MP, f/1.8, (wide), PDAF                                                                                                                                                                                                                                                                         | 477 g (Wi-Fi) / 481 g (LTE) (1.05 lb)               | 248.6 x 179.5 x 7 mm (9.79 x 7.07 x 0.28 in)    |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPhone 14 Pro Max        |           2022 | 6.7 inches, 110.2 cm (~88.3% screen-to-body ratio)  | 1290 x 2796 pixels, 19.5:9 ratio (~460 ppi density) | Li-Ion 4323 mAh (16.68 Wh) | 128GB 6GB RAM, 256GB 6GB RAM, 512GB 6GB RAM, 1TB 6GB RAM                | 12 MP, f/1.9, 23mm (wide), 1/3.6", PDAF, OIS SL 3D, (depth/biometrics sensor)               | 48 MP, f/1.8, 24mm (wide), 1/1.28", 1.22µm, dual pixel PDAF, sensor-shift OIS 12 MP, f/2.8, 77mm (telephoto), 1/3.5", 1.0µm, PDAF, OIS, 3x optical zoom 12 MP, f/2.2, 13mm, 120˚ (ultrawide), 1/2.55", 1.4µm, dual pixel PDAF TOF 3D LiDAR scanner (depth)                                         | 240 g (8.47 oz)                                     | 160.7 x 77.6 x 7.9 mm (6.33 x 3.06 x 0.31 in)   |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPhone 14 Pro            |           2022 | 6.1 inches, 91.7 cm (~87.0% screen-to-body ratio)   | 1179 x 2556 pixels, 19.5:9 ratio (~460 ppi density) | Li-Ion 3200 mAh (12.38 Wh) | 128GB 6GB RAM, 256GB 6GB RAM, 512GB 6GB RAM, 1TB 6GB RAM                | 12 MP, f/1.9, 23mm (wide), 1/3.6", PDAF, OIS (unconfirmed) SL 3D, (depth/biometrics sensor) | 48 MP, f/1.8, 24mm (wide), 1/1.28", 1.22µm, dual pixel PDAF, sensor-shift OIS 12 MP, f/2.8, 77mm (telephoto), 1/3.5", 1.0µm, PDAF, OIS, 3x optical zoom 12 MP, f/2.2, 13mm, 120˚ (ultrawide), 1/2.55", 1.4µm, dual pixel PDAF TOF 3D LiDAR scanner (depth)                                         | 206 g (7.27 oz)                                     | 147.5 x 71.5 x 7.9 mm (5.81 x 2.81 x 0.31 in)   |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPhone 14 Plus           |           2022 | 6.7 inches, 109.8 cm (~87.4% screen-to-body ratio)  | 1284 x 2778 pixels, 19.5:9 ratio (~458 ppi density) | Li-Ion 4323 mAh (16.68 Wh) | 128GB 6GB RAM, 256GB 6GB RAM, 512GB 6GB RAM                             | 12 MP, f/1.9, 23mm (wide), 1/3.6", PDAF SL 3D, (depth/biometrics sensor)                    | 12 MP, f/1.5, 26mm (wide), 1/1.7", 1.9µm, dual pixel PDAF, sensor-shift OIS 12 MP, f/2.4, 13mm, 120˚ (ultrawide)                                                                                                                                                                                   | 203 g (7.16 oz)                                     | 160.8 x 78.1 x 7.8 mm (6.33 x 3.07 x 0.31 in)   |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPhone 14                |           2022 | 6.1 inches, 90.2 cm (~86.0% screen-to-body ratio)   | 1170 x 2532 pixels, 19.5:9 ratio (~460 ppi density) | Li-Ion 3279 mAh (12.68 Wh) | 128GB 6GB RAM, 256GB 6GB RAM, 512GB 6GB RAM                             | 12 MP, f/1.9, 23mm (wide), 1/3.6", PDAF SL 3D, (depth/biometrics sensor)                    | 12 MP, f/1.5, 26mm (wide), 1/1.7", 1.9µm, dual pixel PDAF, sensor-shift OIS 12 MP, f/2.4, 13mm, 120˚ (ultrawide)                                                                                                                                                                                   | 172 g (6.07 oz)                                     | 146.7 x 71.5 x 7.8 mm (5.78 x 2.81 x 0.31 in)   |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple Watch Ultra              |           2022 | 1.92 inches                                         | 502 x 410 pixels (~338 ppi density)                 | Li-Ion 542 mAh             | 32GB                                                                    | N/A                                                                                         | No                                                                                                                                                                                                                                                                                                 | 61.3 g (2.15 oz)                                    | 49 x 44 x 14.4 mm (1.93 x 1.73 x 0.57 in)       |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# ...
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPad Pro 12.9 (2021)     |           2021 | 12.9 inches, 515.3 cm (~85.4% screen-to-body ratio) | 2048 x 2732 pixels, 4:3 ratio (~265 ppi density)    | Li-Po 10758 mAh (40.88 Wh) | 128GB 8GB RAM, 256GB 8GB RAM, 512GB 8GB RAM, 1TB 16GB RAM, 2TB 16GB RAM | 12 MP, f/2.4, 122˚ (ultrawide)                                                              | 12 MP, f/1.8, (wide), 1/3.0", 1.22µm, dual pixel PDAF 10 MP, f/2.4, 125˚ (ultrawide) TOF 3D LiDAR scanner (depth)                                                                                                                                                                                  | 682 g (Wi-Fi), 685 g (5G) (1.50 lb)                 | 280.6 x 214.9 x 6.4 mm (11.05 x 8.46 x 0.25 in) |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPad Pro 11 (2021)       |           2021 | 11.0 inches, 366.5 cm (~82.9% screen-to-body ratio) | 1668 x 2388 pixels (~265 ppi density)               | Li-Po 7538 mAh (28.65 Wh)  | 128GB 8GB RAM, 256GB 8GB RAM, 512GB 8GB RAM, 1TB 16GB RAM, 2TB 16GB RAM | 12 MP, f/2.4, 122˚ (ultrawide)                                                              | 12 MP, f/1.8, (wide), 1/3.0", 1.22µm, dual pixel PDAF 10 MP, f/2.4, 125˚ (ultrawide) TOF 3D LiDAR scanner (depth)                                                                                                                                                                                  | 466 g (Wi-Fi), 470 g (5G) (1.03 lb)                 | 247.6 x 178.5 x 5.9 mm (9.75 x 7.03 x 0.23 in)  |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPhone 12 Pro Max        |           2020 | 6.7 inches, 109.8 cm (~87.4% screen-to-body ratio)  | 1284 x 2778 pixels, 19.5:9 ratio (~458 ppi density) | Li-Ion 3687 mAh (14.13 Wh) | 128GB 6GB RAM, 256GB 6GB RAM, 512GB 6GB RAM                             | 12 MP, f/2.2, 23mm (wide), 1/3.6" SL 3D, (depth/biometrics sensor)                          | 12 MP, f/1.6, 26mm (wide), 1/1.9", 1.7µm, dual pixel PDAF, sensor-shift OIS 12 MP, f/2.2, 65mm (telephoto), 1/3.4", 1.0µm, PDAF, OIS, 2.5x optical zoom 12 MP, f/2.4, 13mm, 120˚ (ultrawide), 1/3.4", 1.0µm TOF 3D LiDAR scanner (depth)                                                           | 228 g (8.04 oz)                                     | 160.8 x 78.1 x 7.4 mm (6.33 x 3.07 x 0.29 in)   |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPhone 12 Pro            |           2020 | 6.1 inches, 90.2 cm (~86.0% screen-to-body ratio)   | 1170 x 2532 pixels, 19.5:9 ratio (~460 ppi density) | Li-Ion 2815 mAh (10.78 Wh) | 128GB 6GB RAM, 256GB 6GB RAM, 512GB 6GB RAM                             | 12 MP, f/2.2, 23mm (wide), 1/3.6" SL 3D, (depth/biometrics sensor)                          | 12 MP, f/1.6, 26mm (wide), 1/2.55", 1.4µm, dual pixel PDAF, OIS 12 MP, f/2.0, 52mm (telephoto), 1/3.4", 1.0µm, PDAF, OIS, 2x optical zoom 12 MP, f/2.4, 13mm, 120˚ (ultrawide), 1/3.4", 1.0µm TOF 3D LiDAR scanner (depth)                                                                         | 189 g (6.67 oz)                                     | 146.7 x 71.5 x 7.4 mm (5.78 x 2.81 x 0.29 in)   |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPhone 12                |           2020 | 6.1 inches, 90.2 cm (~86.0% screen-to-body ratio)   | 1170 x 2532 pixels, 19.5:9 ratio (~460 ppi density) | Li-Ion 2815 mAh (10.78 Wh) | 64GB 4GB RAM, 128GB 4GB RAM, 256GB 4GB RAM                              | 12 MP, f/2.2, 23mm (wide), 1/3.6" SL 3D, (depth/biometrics sensor)                          | 12 MP, f/1.6, 26mm (wide), 1.4µm, dual pixel PDAF, OIS 12 MP, f/2.4, 13mm, 120˚ (ultrawide), 1/3.6"                                                                                                                                                                                                | 164 g (5.78 oz)                                     | 146.7 x 71.5 x 7.4 mm (5.78 x 2.81 x 0.29 in)   |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPhone 12 mini           |           2020 | 5.4 inches, 71.9 cm (~85.1% screen-to-body ratio)   | 1080 x 2340 pixels, 19.5:9 ratio (~476 ppi density) | Li-Ion 2227 mAh (8.57 Wh)  | 64GB 4GB RAM, 128GB 4GB RAM, 256GB 4GB RAM                              | 12 MP, f/2.2, 23mm (wide), 1/3.6" SL 3D, (depth/biometrics sensor)                          | 12 MP, f/1.6, 26mm (wide), 1.4µm, dual pixel PDAF, OIS 12 MP, f/2.4, 13mm, 120˚ (ultrawide), 1/3.6"                                                                                                                                                                                                | 135 g (4.76 oz)                                     | 131.5 x 64.2 x 7.4 mm (5.18 x 2.53 x 0.29 in)   |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPad Air (2020)          |           2020 | 10.9 inches, 359.2 cm (~81.3% screen-to-body ratio) | 1640 x 2360 pixels (~264 ppi density)               | Li-Ion 7606 mAh (28.93 Wh) | 64GB 4GB RAM,  256GB 4GB RAM                                            | 7 MP, f/2.0, 31mm (standard)                                                                | 12 MP, f/1.8, (wide), 1/3.0", 1.22µm, dual pixel PDAF                                                                                                                                                                                                                                              | 458 g (Wi-Fi) / 460 g (3G/LTE) (1.01 lb)            | 247.6 x 178.5 x 6.1 mm (9.75 x 7.03 x 0.24 in)  |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple iPad 10.2 (2020)         |           2020 | 10.2 inches, 324.6 cm (~74.4% screen-to-body ratio) | 1620 x 2160 pixels, 4:3 ratio (~264 ppi density)    | Li-Ion 8827 mAh (32.4 Wh)  | 32GB 3GB RAM, 128GB 3GB RAM                                             | 1.2 MP, f/2.2, 31mm (standard)                                                              | 8 MP, f/2.4, 31mm (standard), 1.12µm, AF                                                                                                                                                                                                                                                           | 490 g (Wi-Fi) / 495 g (LTE) (1.08 lb)               | 250.6 x 174.1 x 7.5 mm (9.87 x 6.85 x 0.30 in)  |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple Watch SE                 |           2020 | 1.78 inches                                         | 448 x 368 pixels (~326 ppi density)                 | Li-Ion                     | 32GB 1GB RAM                                                            | N/A                                                                                         | No                                                                                                                                                                                                                                                                                                 | 36.4 g (1.27 oz)                                    | 44 x 38 x 10.4 mm (1.73 x 1.50 x 0.41 in)       |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
# | Apple Watch Series 6 Aluminum  |           2020 | 1.78 inches                                         | 448 x 368 pixels (~326 ppi density)                 | Li-Ion 303.8 mAh           | 32GB 1GB RAM                                                            | N/A                                                                                         | No                                                                                                                                                                                                                                                                                                 | 36.5 g (1.31 oz)                                    | 44 x 38 x 10.7 mm (1.73 x 1.50 x 0.42 in)       |
# +--------------------------------+----------------+-----------------------------------------------------+-----------------------------------------------------+----------------------------+-------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------+-------------------------------------------------+
#
# Specifications saved to apple_phones_2015_2025.json
